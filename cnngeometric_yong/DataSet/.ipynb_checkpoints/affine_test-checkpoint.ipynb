# %%
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import pandas as pd
from skimage import io

# %%
df = pd.read_csv('data_set.csv')
df.head(2)
# Out:
#                     Source_Image_PATH  \
# 0  center_images/46.408-63.349_13.png
# 1  center_images/46.408-63.349_13.png
#
#                                 Transform_Image_PATH           A11  \
# 0  transformed_images/down_0 right_0 roate_9046.4...  6.123234e-17
# 1  transformed_images/down_0 right_0 roate_18046.... -1.000000e+00
#
#             A12            tx           A21           A22     ty
# 0  1.000000e+00 -1.421085e-14 -1.000000e+00  6.123234e-17  240.0
# 1  1.224647e-16  2.400000e+02 -1.224647e-16 -1.000000e+00  240.0

# %%
source_path = df.iloc[3,0]
targetpath = df.iloc[3,1]
affine = df.iloc[3,2:]
affine= np.array([affine])
affine = affine.astype('float').reshape(2,3)

# %%
source_img= io.imread(source_path)
target_img = io.imread(targetpath)
cv_source = cv2.imread(source_path)
trans_target = cv2.warpAffine(source_img, affine,(source_img.shape[1], source_img.shape[0]))
"""
fig,(ax1, ax2, ax3) = plt.subplots(1,3)
ax1.imshow(source_img)
ax2.imshow(target_img)
ax3.imshow(trans_target)
plt.show()
"""

fig,(ax1, ax2) = plt.subplots(1,2)
ax1.imshow(source_img)
ax1.set_xlabel('Source Image')
ax2.imshow(target_img)
ax1.set_xlabel('Target Image')
plt.show()

# %%
target_img = io.imread(targetpath)
print(targetpath)
plt.imshow(target_img)
plt.show()
# Out:
# transformed_images/down_0 right_20 roate_046.408-63.349_13.png

# %%
cv_source = cv2.imread(source_path)
trans_target = cv2.warpAffine(source_img, affine,(source_img.shape[1], source_img.shape[0]))
plt.imshow(trans_target)
plt.show()
